# %%
import Pkg
Pkg.develop(path="/Users/manabu/work/ggblab/julia/GeoGebra.jl")
Pkg.instantiate()
Pkg.precompile()
using GeoGebra
# Out:
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [c0ffee00] + GeoGebra v0.1.0 `~/work/ggblab/julia/GeoGebra.jl`
#     Updating `~/.julia/environments/v1.12/Manifest.toml`
#   [c0ffee00] + GeoGebra v0.1.0 `~/work/ggblab/julia/GeoGebra.jl`
# Precompiling packages...
#     621.7 ms  ✓ GeoGebra
#   1 dependency successfully precompiled in 1 seconds. 125 already precompiled.

# %%
GeoGebra.set_default_port(61490)
# Out:
# 61490

# %%
# stores reply in x (unwrapped)
x = @ggblab (0,0)
# Out:
# "B"

# %%
y = @ggblab Circle(x, 1)
# Out:
# "e"

# %%
z = GeoGebra.send_command(:Circle, x, 1)
# Out:
# "f"

# %%
# x is evaluated at runtime and interpolated into command
z = @ggblab api getVersion()
# Out:
# Dict{String, Any} with 1 entry:
#   "value" => "5.2.909.9"
