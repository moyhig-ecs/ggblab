# %%
using CondaPkg
CondaPkg.add_pip("ggblab", version="@ file:///Users/manabu/work/ggblab/dist/ggblab-1.7.0-py3-none-any.whl")
# Out:
#     CondaPkg Found dependencies: /Users/manabu/.julia/environments/v1.12/CondaPkg.toml
#     CondaPkg Found dependencies: /Users/manabu/.julia/packages/PythonCall/83z4q/CondaPkg.toml
#     CondaPkg Found dependencies: /Users/manabu/.julia/packages/CondaPkg/HctRf/CondaPkg.toml
#     CondaPkg Initialising pixi
#              │ /Users/manabu/.julia/artifacts/d2fecc2a9fa3eac2108d3e4d9d155e6ff5dfd0b2/bin/pixi
#              │ init
#              │ --format pixi
#              └ /Users/manabu/.julia/environments/v1.12/.CondaPkg
# ✔ Created /Users/manabu/.julia/environments/v1.12/.CondaPkg/pixi.toml
#     CondaPkg Wrote /Users/manabu/.julia/environments/v1.12/.CondaPkg/pixi.toml
#              │ [dependencies]
#              │ openssl = ">=3, <3.6"
#              │ uv = ">=0.4"
#              │
#              │     [dependencies.python]
#              │     channel = "conda-forge"
#              │     build = "*cp*"
#              │     version = ">=3.10,!=3.14.0,!=3.14.1,<4"
#              │
#              │ [project]
#              │ name = ".CondaPkg"
#              │ platforms = ["osx-arm64"]
#              │ channels = ["conda-forge"]
#              │ channel-priority = "strict"
#              │ description = "automatically generated by CondaPkg.jl"
#              │
#              │ [pypi-dependencies]
#              │ requests = "*"
#              │
#              │     [pypi-dependencies.ggblab]
#              └     path = "/Users/manabu/work/ggblab/dist/ggblab-1.7.0-py3-none-any.whl"
#     CondaPkg Installing packages
#              │ /Users/manabu/.julia/artifacts/d2fecc2a9fa3eac2108d3e4d9d155e6ff5dfd0b2/bin/pixi
#              │ install
#              └ --manifest-path /Users/manabu/.julia/environments/v1.12/.CondaPkg/pixi.toml
# ✔ The default environment has been installed.

# %%
import Pkg
Pkg.develop(path="/Users/manabu/work/ggblab/julia/GeoGebra.jl")
Pkg.instantiate()
Pkg.precompile()
using GeoGebra
# Out:
#    Resolving package versions...
#      Project No packages added to or removed from `~/.julia/environments/v1.12/Project.toml`
#     Manifest No packages added to or removed from `~/.julia/environments/v1.12/Manifest.toml`

# %%
GeoGebra.set_default_port(50243)
# Out:
# 50243

# %%
# stores reply in x (unwrapped)
x = @ggblab (0,0)
# Out:
# "E"

# %%
y = @ggblab Circle(:A, 1)
# Out:
# "c"

# %%
z = GeoGebra.send_command(:Circle, x, 1)
# Out:
# "d"

# %%
# x is evaluated at runtime and interpolated into command
z = @ggblab api getVersion()
# Out:
# "5.2.909.9"

# %%
GeoGebra.send_function("getVersion")
# Out:
# "5.2.909.9"

# %%
using PythonCall

# %%
ggb = pyimport("ggblab")
# Out:
# Python: <ggblab.ggbapplet.GeoGebra object at 0x15dcbf380>

# %%
ggb.connect_to_bridge(host="127.0.0.1", port=50243)
# Out:
# Python: True

# %%
@await ggb.function("getVersion")
# Out:
# Python: '5.2.909.9'

# %%
pl = pyimport("polars")
# Out:
# Python: <module 'polars' from '/Users/manabu/.julia/environments/v1.12/.CondaPkg/.pixi/envs/default/lib/python3.14/site-packages/polars/__init__.py'>

# %%
df2.filter(~pl.col("Name").is_in(["A"]))
# Out:
# Python:
# shape: (6, 10)
# ┌──────────┬──────┬────────┬──────────────┬───┬───────┬────────────┬───────────…
# │ Sequence ┆ Name ┆ Type   ┆ Command      ┆ … ┆ Layer ┆ ShowObject ┆ ShowLabel …
# │ ---      ┆ ---  ┆ ---    ┆ ---          ┆   ┆ ---   ┆ ---        ┆ ---       …
# │ u32      ┆ str  ┆ str    ┆ str          ┆   ┆ u32   ┆ bool       ┆ bool      …
# ╞══════════╪══════╪════════╪══════════════╪═══╪═══════╪════════════╪═══════════…
# │ 2        ┆ B    ┆ point  ┆ (0, 0)       ┆ … ┆ 0     ┆ false      ┆ false     …
# │ 3        ┆ C    ┆ point  ┆ (0, 0)       ┆ … ┆ 0     ┆ false      ┆ false     …
# │ 4        ┆ c    ┆ circle ┆ Circle(A, 1) ┆ … ┆ 0     ┆ true       ┆ true      …
# │ 5        ┆ d    ┆ circle ┆ Circle(C, 1) ┆ … ┆ 0     ┆ true       ┆ true      …
# │ 6        ┆ D    ┆ point  ┆ (0, 0)       ┆ … ┆ 0     ┆ false      ┆ false     …
# │ 7        ┆ E    ┆ point  ┆ (0, 0)       ┆ … ┆ 0     ┆ false      ┆ false     …
# └──────────┴──────┴────────┴──────────────┴───┴───────┴────────────┴───────────…

# %%
ggbex_sympy = pyimport("ggblab_extra.sympy")
# Out:
# Python: <module 'ggblab_extra.sympy' from '/Users/manabu/.julia/environments/v1.12/.CondaPkg/.pixi/envs/default/lib/python3.14/site-packages/ggblab_extra/sympy/__init__.py'>

# %%
df3 = ggbex_sympy.attach_object2d(df2)["Name", "Type", "object2d"]
# Out:
# Python:
# shape: (7, 3)
# ┌──────┬────────┬─────────────────────────────────┐
# │ Name ┆ Type   ┆ object2d                        │
# │ ---  ┆ ---    ┆ ---                             │
# │ str  ┆ str    ┆ object                          │
# ╞══════╪════════╪═════════════════════════════════╡
# │ A    ┆ point  ┆ Object2D(kind='point', obj=Poi… │
# │ B    ┆ point  ┆ Object2D(kind='point', obj=Poi… │
# │ C    ┆ point  ┆ Object2D(kind='point', obj=Poi… │
# │ c    ┆ circle ┆ Object2D(kind='circle', obj=Ci… │
# │ d    ┆ circle ┆ Object2D(kind='circle', obj=Ci… │
# │ D    ┆ point  ┆ Object2D(kind='point', obj=Poi… │
# │ E    ┆ point  ┆ Object2D(kind='point', obj=Poi… │
# └──────┴────────┴─────────────────────────────────┘

# %%
c = df3.filter(pl.col("Name").is_in(["c"]))["object2d"].item().obj
# Out:
# Python: Circle(Point2D(0, 0), 1)

# %%
c.center
# Out:
# Python: Point2D(0, 0)

# %%
nx = pyimport("networkx")
# Out:
# Python: <module 'networkx' from '/Users/manabu/.julia/environments/v1.12/.CondaPkg/.pixi/envs/default/lib/python3.14/site-packages/networkx/__init__.py'>

# %%
p = ggbex.ConstructionTreeParser(df2)
# Out:
# Python: <ggblab_extra.construction_parser.ConstructionTreeParser object at 0x31866d010>

# %%
g1 = p.parse()
# Out:
# Python: <networkx.classes.digraph.DiGraph object at 0x3184b1bd0>
# Warning: Could not increment key 'Circle': database is locked
# Warning: Could not increment key 'Circle': database is locked

# %%
nx.write_network_text(g1)
# Out:
# Python: None
# ╟── A
# ╎   └─╼ c
# ╙── C
#     └─╼ d

# %%
df2 = @await ConstructionIO.initialize_dataframe(ggb, use_applet=true)
# Out:
# Python:
# shape: (7, 10)
# ┌──────────┬──────┬────────┬──────────────┬───┬───────┬────────────┬───────────…
# │ Sequence ┆ Name ┆ Type   ┆ Command      ┆ … ┆ Layer ┆ ShowObject ┆ ShowLabel …
# │ ---      ┆ ---  ┆ ---    ┆ ---          ┆   ┆ ---   ┆ ---        ┆ ---       …
# │ u32      ┆ str  ┆ str    ┆ str          ┆   ┆ u32   ┆ bool       ┆ bool      …
# ╞══════════╪══════╪════════╪══════════════╪═══╪═══════╪════════════╪═══════════…
# │ 1        ┆ A    ┆ point  ┆ (0, 0)       ┆ … ┆ 0     ┆ false      ┆ false     …
# │ 2        ┆ B    ┆ point  ┆ (0, 0)       ┆ … ┆ 0     ┆ false      ┆ false     …
# │ 3        ┆ C    ┆ point  ┆ (0, 0)       ┆ … ┆ 0     ┆ false      ┆ false     …
# │ 4        ┆ c    ┆ circle ┆ Circle(A, 1) ┆ … ┆ 0     ┆ true       ┆ true      …
# │ 5        ┆ d    ┆ circle ┆ Circle(C, 1) ┆ … ┆ 0     ┆ true       ┆ true      …
# │ 6        ┆ D    ┆ point  ┆ (0, 0)       ┆ … ┆ 0     ┆ false      ┆ false     …
# │ 7        ┆ E    ┆ point  ┆ (0, 0)       ┆ … ┆ 0     ┆ false      ┆ false     …
# └──────────┴──────┴────────┴──────────────┴───┴───────┴────────────┴───────────…

# %%
c = ggb.file.load("2025_06_08.ggb")
# Out:
# Python: <ggblab.file.ggb_file object at 0x165a7f230>

# %%
o = c.ggb_schema.decode(c.geogebra_xml)
o
# Out:
# Python: {'@title': '', '@author': '', '@date': '', 'element': [{'@type': 'point', '@label': 'O_2', 'show': [{'@object': True, '@label': True, '@ev': 4}], 'objColor': [{'@r': 21, '@g': 101, '@b': 192, '@alpha': 0.0}], 'layer': [{'@val': 9}], 'labelMode': [{'@val': 0}], 'animation': [{'@step': '0.1', '@type': 1, '@playing': False}], 'pointSize': [{'@val': 5.0}], 'pointStyle': [{'@val': 0}], 'coords': [{'@x': '-2.1329263317451677', '@y': '-0.09778495143965732', '@z': '1'}]}, {'@type': 'point', '@label': 'A', 'show': [{'@object': True, '@label': True, '@ev': 4}], 'objColor': [{'@r': 176, '@g': 0, '@b': 32, '@alpha': 0.0}], 'layer': [{'@val': 2}], 'labelMode': [{'@val': 0}], 'animation': [{'@step': '0.1', '@type': 1, '@playing': False}], 'pointSize': [{'@val': 5.0}], 'pointStyle': [{'@val': 0}], 'coords': [{'@x': '10', '@y': '0', '@z': '1'}]}, {'@type': 'point', '@label': 'B', 'show': [{'@object': True, '@label': False, '@ev': 4}], 'objColor': [{'@r': 21, '@g': 101, '@b': 192, '@alpha': 0.0}], 'layer': [{'@val': 9}], 'labelMode':
#                             ... 45374 more chars ...
# e': 'Intersect', 'input': {'@a0': 'c', '@a1': 'd_2'}, 'output': {'@a0': 'T', '@a1': ''}}, {'@name': 'Angle', 'input': {'@a0': 'F_2', '@a1': 'C', '@a2': 'O_2'}, 'output': {'@a0': 'ι'}}, {'@name': 'Angle', 'input': {'@a0': 'I', '@a1': 'C', '@a2': 'O_2'}, 'output': {'@a0': 'κ'}}, {'@name': 'Angle', 'input': {'@a0': 'R', '@a1': 'C', '@a2': 'O_1'}, 'output': {'@a0': 'λ'}}, {'@name': 'Angle', 'input': {'@a0': 'F_2', '@a1': 'C', '@a2': 'O_1'}, 'output': {'@a0': 'μ'}}, {'@name': 'Intersect', 'input': {'@a0': 'h_1', '@a1': 'l_1'}, 'output': {'@a0': 'U'}}, {'@name': 'AngularBisector', 'input': {'@a0': 'k_1', '@a1': 'm_1'}, 'output': {'@a0': 'h_3', '@a1': 'i_3'}}, {'@name': 'Angle', 'input': {'@a0': 'O_1', '@a1': 'C', '@a2': 'O_2'}, 'output': {'@a0': 'ν'}}, {'@name': 'Angle', 'input': {'@a0': 'O_1', '@a1': 'A', '@a2': 'Q'}, 'output': {'@a0': 'η'}}, {'@name': 'Angle', 'input': {'@a0': 'O_1', '@a1': 'A', '@a2': 'F_1'}, 'output': {'@a0': 'ζ'}}, {'@name': 'Angle', 'input': {'@a0': 'O_2', '@a1': 'A', '@a2': 'F_1'}, 'output': {'@a0': 'ε'}}]}

# %%
ggbex = pyimport("ggblab_extra")
# Out:
# Python: <module 'ggblab_extra' from '/Users/manabu/.julia/environments/v1.12/.CondaPkg/.pixi/envs/default/lib/python3.14/site-packages/ggblab_extra/__init__.py'>

# %%
ConstructionIO = ggbex.ConstructionIO
# Out:
# Python: <class 'ggblab_extra.construction_io.ConstructionIO'>

# %%
@await ConstructionIO.initialize_dataframe(ggb, file="2025_13_01.ggb")
# Out:
# Python:
# shape: (170, 10)
# ┌──────────┬───────────┬─────────┬────────────────┬───┬───────┬────────────┬───…
# │ Sequence ┆ Name      ┆ Type    ┆ Command        ┆ … ┆ Layer ┆ ShowObject ┆ Sh…
# │ ---      ┆ ---       ┆ ---     ┆ ---            ┆   ┆ ---   ┆ ---        ┆ --…
# │ u32      ┆ str       ┆ str     ┆ str            ┆   ┆ u32   ┆ bool       ┆ bo…
# ╞══════════╪═══════════╪═════════╪════════════════╪═══╪═══════╪════════════╪═══…
# │ 1        ┆ C         ┆ point   ┆ null           ┆ … ┆ 9     ┆ true       ┆ tr…
# │ 2        ┆ A         ┆ point   ┆ null           ┆ … ┆ 9     ┆ true       ┆ tr…
# │ 3        ┆ poly1     ┆ polygon ┆ Polygon(C, A,  ┆ … ┆ 3     ┆ false      ┆ fa…
# │          ┆           ┆         ┆ 4)             ┆   ┆       ┆            ┆   …
# │ 4        ┆ f         ┆ segment ┆ Segment(C, A,  ┆ … ┆ 2     ┆ false      ┆ fa…
# │          ┆           ┆         ┆ poly1)         ┆   ┆       ┆            ┆   …
# │ 5        ┆ g         ┆ segment ┆ Segment(A, E,  ┆ … ┆ 2     ┆ false      ┆ fa…
#                              ... 299 more lines ...
# │          ┆           ┆         ┆ B_1, A_1)      ┆   ┆       ┆            ┆   …
# │ 166      ┆ b_3       ┆ segment ┆ Segment(P,     ┆ … ┆ 2     ┆ false      ┆ fa…
# │          ┆           ┆         ┆ B_1, t8)       ┆   ┆       ┆            ┆   …
# │ 167      ┆ p_6       ┆ segment ┆ Segment(B_1,   ┆ … ┆ 2     ┆ false      ┆ fa…
# │          ┆           ┆         ┆ A_1, t8)       ┆   ┆       ┆            ┆   …
# │ 168      ┆ e_3       ┆ segment ┆ Segment(A_1,   ┆ … ┆ 2     ┆ false      ┆ fa…
# │          ┆           ┆         ┆ P, t8)         ┆   ┆       ┆            ┆   …
# │ 169      ┆ text5_3   ┆ text    ┆ "$proj_{\vec{a ┆ … ┆ 9     ┆ false      ┆ fa…
# │          ┆           ┆         ┆ }}\ \vec{b} =  ┆   ┆       ┆            ┆   …
# │          ┆           ┆         ┆ \f…            ┆   ┆       ┆            ┆   …
# │ 170      ┆ η         ┆ angle   ┆ Angle(C, A, B) ┆ … ┆ 6     ┆ false      ┆ tr…
# └──────────┴───────────┴─────────┴────────────────┴───┴───────┴────────────┴───…

# %%
using GeoGebra, JSON
payload = Dict("type"=>"function", "payload"=>Dict("name"=>"getVersion", "args"=>[]))
println(JSON.json(payload))
println(GeoGebra.request(payload; timeout=5.0))
# Out:
# {"payload":{"name":"getVersion","args":[]},"type":"function"}
# JSON.Object{String, Any}("value" => "5.2.909.9")

# %%
using Pkg

# %%
Pkg.add("JSON")
# Out:
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [682c06a0] + JSON v1.4.0
#     Manifest No packages added to or removed from `~/.julia/environments/v1.12/Manifest.toml`

# %%
using GeoGebra
# 一時的に呼ぶ場合
GeoGebra.send_function("getVersion"; port=54294)
# または恒久的にデフォルトを変更
# Out:
# JSON.Object{String, Any} with 1 entry:
#   "message" => "Handler execution failed"

# %%
GeoGebra.set_default_port(54294)
GeoGebra.send_function("getXML")
# Out:
# JSON.Object{String, Any} with 1 entry:
#   "message" => "Handler execution failed"

# %%
    z = GeoGebra.send_command(:Circle, x, 1)
# Out:
# "f"

# %%
using PyCall

# %%
py"""
import ggblab
"""
# Out:
# PyError ($(Expr(:escape, :(ccall(#= /Users/manabu/.julia/packages/PyCall/1gn3u/src/pyeval.jl:38 =# @pysym(:PyEval_EvalCode), PyPtr, (PyPtr, PyPtr, PyPtr), o, globals, locals))))) <class 'ModuleNotFoundError'>
# ModuleNotFoundError("No module named 'ggblab'")
#   File "/Users/manabu/.julia/packages/PyCall/1gn3u/src/pyeval.jl", line 1, in <module>
#     const Py_single_input = 256  # from Python.h
#     ^^^^^^^^^^^^^
#
#
# Stacktrace:
#   [1] pyerr_check(msg::String, val::Nothing)
#     @ PyCall ~/.julia/packages/PyCall/1gn3u/src/exception.jl:75
#   [2] pyerr_check(msg::String)
#     @ PyCall ~/.julia/packages/PyCall/1gn3u/src/exception.jl:79
#   [3] _handle_error(msg::String)
#     @ PyCall ~/.julia/packages/PyCall/1gn3u/src/exception.jl:96
#   [4] macro expansion
#     @ ~/.julia/packages/PyCall/1gn3u/src/exception.jl:110 [inlined]
#   [5] #pyeval_##0
#     @ ~/.julia/packages/PyCall/1gn3u/src/pyeval.jl:38 [inlined]
#   [6] disable_sigint
#     @ ./c.jl:167 [inlined]
#   [7] pyeval_(s::String, globals::PyDict{…}, locals::PyDict{…}, input_type::Int64, fname::String)
#     @ PyCall ~/.julia/packages/PyCall/1gn3u/src/pyeval.jl:37
#   [8] top-level scope
#     @ In[17]:1
#   [9] macro expansion
#     @ ~/.julia/packages/PyCall/1gn3u/src/pyeval.jl:230 [inlined]
#  [10] eval(m::Module, e::Any)
#     @ Core ./boot.jl:489
# Some type information was truncated. Use `show(err)` to see complete types.

# %%
pushfirst!(pyimport("sys")."path", "/Users/manabu/work/ggblab")
# Now you can import
my_module = pyimport("ggblab")
# Out:
# PyError (PyImport_ImportModule
#
# The Python package ggblab could not be imported by pyimport. Usually this means
# that you did not install ggblab in the Python version being used by PyCall.
#
# PyCall is currently configured to use the Julia-specific Python distribution
# installed by the Conda.jl package.  To install the ggblab module, you can
# use `pyimport_conda("ggblab", PKG)`, where PKG is the Anaconda
# package that contains the module ggblab, or alternatively you can use the
# Conda package directly (via `using Conda` followed by `Conda.add` etcetera).
#
# Alternatively, if you want to use a different Python distribution on your
# system, such as a system-wide Python (as opposed to the Julia-specific Python),
# you can re-configure PyCall with that Python.   As explained in the PyCall
# documentation, set ENV["PYTHON"] to the path/name of the python executable
# you want to use, run Pkg.build("PyCall"), and re-launch Julia.
#
# ) <class 'ModuleNotFoundError'>
# ModuleNotFoundError("No module named 'IPython'")
#   File "/Users/manabu/work/ggblab/ggblab/__init__.py", line 43, in <module>
#     from .comm import ggb_comm, ggb_comm_instance
#   File "/Users/manabu/work/ggblab/ggblab/comm.py", line 11, in <module>
#     from ggblab_core2.comm import *  # noqa: F401,F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/manabu/work/ggblab/ggblab_core2/comm.py", line 17, in <module>
#     from IPython import get_ipython
#
#
# Stacktrace:
#  [1] pyimport(name::String)
#    @ PyCall ~/.julia/packages/PyCall/1gn3u/src/PyCall.jl:558
#  [2] top-level scope
#    @ In[18]:3
#  [3] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489

# %%
using Conda

# %%
Conda.pip_interop(true, :conda_jl)
# Out:
# [ Info: Running `conda config --set pip_interop_enabled true --file /Users/manabu/.julia/conda/3/aarch64/envs/conda_jl/condarc-julia.yml` in conda_jl environment
# WARNING conda.cli.condarc:set_key(484): Key pip_interop_enabled is an alias of prefix_data_interoperability; setting value with latter

# %%
Conda.pip("install", "ggblab", :conda_jl)
# Out:
# pip_interop is not enabled
# Use `Conda.pip_interop(true; [env::Environment=ROOTENV])` to enable
#
#
# Stacktrace:
#  [1] error(s::String)
#    @ Base ./error.jl:44
#  [2] check_pip_interop
#    @ ~/.julia/packages/Conda/05AVg/src/Conda.jl:637 [inlined]
#  [3] pip(cmd::String, pkgs::String, env::Symbol)
#    @ Conda ~/.julia/packages/Conda/05AVg/src/Conda.jl:666
#  [4] top-level scope
#    @ In[40]:1
#  [5] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489

# %%
ENV["CONDA_JL_HOME"] = "/Users/manabu/miniforge3/envs/py314"
# Out:
# "/Users/manabu/miniforge3/envs/py314"

# %%
Conda.ROOTENV
# Out:
# "/Users/manabu/.julia/conda/3/aarch64"
