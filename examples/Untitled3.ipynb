# %%
# %load_ext autoreload
# %autoreload 2

# %%
import ggblab

# %%
# %ggblab api getVersion()
# Out:
# [ggblab] created GeoGebra singleton and stored as 'ggb' in user namespace
# '5.2.909.9'

# %%
import polars as pl

# %%
from ggblab_extra.sympy import attach_object2d, attach_object3d, enumerate_plane_members

# %%
from ggblab_extra import ConstructionIO
from ggblab_extra import ConstructionTreeParser

# %%
df = await ConstructionIO.initialize_dataframe(ggb, use_applet=True)

# %%
df2 = attach_object2d(df)

# %%
df2["Name", "Command", "Value", "object2d"]
# Out:
# shape: (6, 4)
# ┌──────┬──────────────┬─────────────────────────────────┬─────────────────────────────────┐
# │ Name ┆ Command      ┆ Value                           ┆ object2d                        │
# │ ---  ┆ ---          ┆ ---                             ┆ ---                             │
# │ str  ┆ str          ┆ str                             ┆ object                          │
# ╞══════╪══════════════╪═════════════════════════════════╪═════════════════════════════════╡
# │ A    ┆ null         ┆ A = (-1.71, 1.16)               ┆ Object2D(kind='point', obj=Poi… │
# │ B    ┆ null         ┆ B = (2.31, -2.42)               ┆ Object2D(kind='point', obj=Poi… │
# │ c    ┆ Circle(A, B) ┆ c: (x + 1.71)² + (y - 1.16)² =… ┆ Object2D(kind='circle', obj=Ci… │
# │ C    ┆ null         ┆ C = (-0.75, -2.78)              ┆ Object2D(kind='point', obj=Poi… │
# │ D    ┆ null         ┆ D = (4.21, 4.26)                ┆ Object2D(kind='point', obj=Poi… │
# │ f    ┆ Line(C, D)   ┆ f: -7.04x + 4.96y = -8.5088     ┆ Object2D(kind='line', obj=Line… │
# └──────┴──────────────┴─────────────────────────────────┴─────────────────────────────────┘

# %%
o1 = df2.filter(pl.col("Name") == "c")["object2d"].item().obj

# %%
o2 = df2.filter(pl.col("Name") == "f")["object2d"].item().obj

# %%
o1, o2
# Out:
# (Circle(Point2D(-171/100, 29/25), 107660206204521/20000000000000),
#  Line2D(Point2D(0, -85774193548387/50000000000000), Point2D(-124/25, -437774193548387/50000000000000)))

# %%
p1, p2 = (o1.equation(x=x, y=y), o2.equation(x=x, y=y))

# %%
p1, p2
# Out:
# ((x + 171/100)**2 + (y - 29/25)**2 - 11590719999999982024480839441/400000000000000000000000000,
#  176*x/25 - 124*y/25 - 2658999999999997/312500000000000)

# %%
p2.subs({x: 3, y:4})
# Out:
# -2258999999999997/312500000000000

# %%
from sympy import nonlinsolve, linsolve, solve, Eq, discriminant
from sympy import symbols
x, y, z = symbols('x y z')

# %%
s = solve(Eq(p2, 0), y)
s
# Out:
# [44*x/31 - 85774193548387/50000000000000]

# %%
discriminant(p1.subs({y: s[0]})).evalf()
# Out:
# 236.940708428720

# %%
p1.subs({y: s[0]})
# Out:
# (x + 171/100)**2 + (44*x/31 - 143774193548387/50000000000000)**2 - 11590719999999982024480839441/400000000000000000000000000

# %%
s2 = nonlinsolve([p1.subs({y: s[0]})], [x])
s2
# Out:
# {(28485624999999967/36212500000000000 - 31*sqrt(569250051999998895379024796514389)/289700000000000000,), (28485624999999967/36212500000000000 + 31*sqrt(569250051999998895379024796514389)/289700000000000000,)}

# %%
# [(e[0].evalf(), e[1].evalf()) 
[e[0].evalf() for e in s2]
# Out:
# [-1.76645775557178, 3.33970594335224]

# %%
o1.intersect(o2).evalf()
# Out:
# {Point2D(-1.76645775557178, -4.22271423371479), Point2D(3.33970594335224, 3.02474391959673)}

# %%
s2 = nonlinsolve([p1, p2], [x, y])

# %%
[(e[0].evalf(), e[1].evalf()) for e in s2]
# Out:
# [(-1.76645775557178, -4.22271423371479), (3.33970594335224, 3.02474391959673)]
