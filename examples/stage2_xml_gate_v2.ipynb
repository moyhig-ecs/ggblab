# %%
import json, time, sys
sys.path.insert(0, '/Users/manabu/work/ggblab-replay')
import ggblab.host.html_host as H
H.DEPLOY = 'https://cdn.geogebra.org/apps/deployggb.js'   # same deployggb source as v1 createApplet.ts
from ggblab import GeoGebra
from ggblab.host.base import Eval
GROUPS = json.load(open('/private/tmp/claude-501/-Users-manabu-lancedb-rag/fd32421b-f579-4fc8-aad6-f0fe35d00c39/scratchpad/gate2/groups.json'))
PARAMS = dict(appName='suite', showToolBar=True, showZoomButtons=True, showAlgebraInput=True, showMenuBar=True, algebraInputPosition='top')
print('groups', [(g['id'], len(g['v2'])) for g in GROUPS if not g['has_dynamic']])

# %%
g0 = GeoGebra(**PARAMS); g0

# %%
t0 = time.time(); labels0 = g0.command(*GROUPS[0]['v2'], timeout=60); xml0 = g0.xml(timeout=60)
open('/private/tmp/claude-501/-Users-manabu-lancedb-rag/fd32421b-f579-4fc8-aad6-f0fe35d00c39/scratchpad/gate2/v2_g0.xml', 'w').write(xml0); print('g0', len(GROUPS[0]['v2']), 'cmds', round(time.time()-t0, 2), 's', 'XML_LEN', len(xml0), str(labels0)[:160])

# %%
g1 = GeoGebra(**PARAMS); g1

# %%
t0 = time.time(); labels1 = g1.command(*GROUPS[1]['v2'], timeout=60); xml1 = g1.xml(timeout=60)
open('/private/tmp/claude-501/-Users-manabu-lancedb-rag/fd32421b-f579-4fc8-aad6-f0fe35d00c39/scratchpad/gate2/v2_g1.xml', 'w').write(xml1); print('g1', len(GROUPS[1]['v2']), 'cmds', round(time.time()-t0, 2), 's', 'XML_LEN', len(xml1), str(labels1)[:160])

# %%
g2 = GeoGebra(**PARAMS); g2

# %%
t0 = time.time(); labels2 = g2.command(*GROUPS[2]['v2'], timeout=60); xml2 = g2.xml(timeout=60)
open('/private/tmp/claude-501/-Users-manabu-lancedb-rag/fd32421b-f579-4fc8-aad6-f0fe35d00c39/scratchpad/gate2/v2_g2.xml', 'w').write(xml2); print('g2', len(GROUPS[2]['v2']), 'cmds', round(time.time()-t0, 2), 's', 'XML_LEN', len(xml2), str(labels2)[:160])

# %%
g3 = GeoGebra(**PARAMS); g3

# %%
t0 = time.time(); labels3 = g3.command(*GROUPS[3]['v2'], timeout=60); xml3 = g3.xml(timeout=60)
open('/private/tmp/claude-501/-Users-manabu-lancedb-rag/fd32421b-f579-4fc8-aad6-f0fe35d00c39/scratchpad/gate2/v2_g3.xml', 'w').write(xml3); print('g3', len(GROUPS[3]['v2']), 'cmds', round(time.time()-t0, 2), 's', 'XML_LEN', len(xml3), str(labels3)[:160])
