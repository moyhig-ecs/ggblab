# %% [markdown]
# # GeoGebra applet interaction listen on Python

# %%
# this magic for develop only
# %load_ext autoreload
# %autoreload 2

# %%
import asyncio

# %%
from ggblab import GeoGebra

# %%
# open GeoGebra Widget on left-side
# ggb = await GeoGebra().init()
ggb = await GeoGebra().init(use_vscode=True)
# Out:
# Using local cached file: xsd/common.xsd

# %%
# case 1 of interactions: algebraic command
# [GeoGebra Manual :: GeoGebra Manual]
# (https://geogebra.github.io/docs/manual/)

# %%
await ggb.command("O = (0, 0)")
await ggb.command("c1 = Circle(O, 1)")
await ggb.command("A = (1, 0)")
await ggb.command("c2 = Circle(A, 1)")
await ggb.command("l1 = {Intersect(c1, c2)}")
await ggb.command("a = Length(l1)")
# Out:
# 'a'

# %%
ggb.comm.logs
# Out:
# ['Clients connected: 1 (connects+=1, disconnects+=0)',
#  'recv:type=probe',
#  'recv:type=start',
#  'Unexpected response for id fd7126f9-41f2-4b29-b7cf-6bdc1d7827af',
#  'post_execute: event probe',
#  'post_execute: event start',
#  'post_execute: flushed 2 recv_events',
#  'Clients connected: 1 (connects+=2, disconnects+=2)',
#  'recv:type=created',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'Unexpected response for id a494dd06-3597-42ba-86c5-b077f04cff09',
#  'post_execute: event add',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 2 recv_events',
#  'recv:type=created',
#  'Unexpected response for id 0c1b05d7-2ab4-4e83-b18d-662fd14c280e',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=created',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'Unexpected response for id 9b12c8c1-e86d-4cf3-855a-43d993a4a7bd',
#  'post_execute: event add',
#  'post_execute: event bulk_actions',
#  'post_execute: event add',
#  'post_execute: flushed 3 recv_events',
#  'recv:type=created',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'Unexpected response for id d0a373a5-a770-442b-9c27-5420c41aa915',
#  'post_execute: event bulk_actions',
#  'post_execute: event add',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 3 recv_events',
#  'recv:type=created',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'Unexpected response for id 14025bac-2b3f-4a41-b9d3-21a8ce336034',
#  'post_execute: event add',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 2 recv_events',
#  'recv:type=created',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'post_execute: event add',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 2 recv_events',
#  'Unexpected response for id 8cb63443-6e20-44d6-96b6-7bbc183e2379',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 2 recv_events',
#  'recv:type=listen',
#  'Unexpected response for id 201600ae-6974-4943-89d1-c14b13b48945',
#  'recv:type=created',
#  'Unexpected response for id 4f152083-c893-4da2-98b5-c0b1f5622cf2',
#  'recv:type=value',
#  'Unexpected response for id 4b4eda28-4928-4af2-a9d2-30e49bc0dbb8',
#  'Clients connected: 1 (connects+=16, disconnects+=16)',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 2 recv_events',
#  'recv:type=created',
#  'Unexpected response for id 17d38657-45ff-4731-814b-bf04eb13e092',
#  'recv:type=value',
#  'Unexpected response for id 487bf2b7-fa92-4d50-88b8-c1bdd9cfbae7',
#  'recv:type=created',
#  'Unexpected response for id b0bb7280-fde8-4941-90f1-9d936e530dc5',
#  'recv:type=value',
#  'Clients connected: 1 (connects+=5, disconnects+=5)',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 6 recv_events',
#  'Clients connected: 1 (connects+=3, disconnects+=3)',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 20 recv_events',
#  'Clients connected: 1 (connects+=10, disconnects+=10)',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 2 recv_events',
#  'Clients connected: 1 (connects+=1, disconnects+=1)',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 14 recv_events',
#  'Clients connected: 1 (connects+=1, disconnects+=0)',
#  'recv:type=probe',
#  'recv:type=start',
#  'Unexpected response for id 8c470534-059e-47a9-b84d-600b84c075f8',
#  'post_execute: event probe',
#  'post_execute: event start',
#  'post_execute: flushed 2 recv_events',
#  'Clients connected: 1 (connects+=2, disconnects+=2)',
#  'recv:type=created',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'Unexpected response for id 76e5553c-15b0-4814-b713-47d70c1bea17',
#  'post_execute: event add',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 2 recv_events',
#  'recv:type=created',
#  'Unexpected response for id c7f80ddc-b75a-44b1-a861-dead17d7ff85',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=created',
#  'Unexpected response for id 6a5eeb5e-eefb-40ff-8642-29145d0790ef',
#  'post_execute: event add',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 2 recv_events',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'recv:type=created',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'Unexpected response for id 091874a5-f2e2-4df4-8b02-0f67d88994b5',
#  'post_execute: event add',
#  'post_execute: event bulk_actions',
#  'post_execute: event add',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 4 recv_events',
#  'recv:type=created',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1',
#  'Unexpected response for id 184ffa9a-111f-4a21-96aa-4ad5be054d62',
#  'post_execute: event add',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 2 recv_events',
#  'recv:type=created',
#  'recv:type=bulk_actions',
#  'bulk_actions: packaged_count=1']

# %%
# moveing Point 'A', 'a' corresponds number of intersecting points
# but GeoGebra returns 1 even when no intersection...
r = await ggb.listen('a')

await asyncio.sleep(.01)
ggb.comm.shared_objects
# Out:
# {'a': 'a = 2'}

# %%
await ggb.command("A = (1, 0)")
await asyncio.sleep(.01)
ggb.comm.shared_objects
# Out:
# {'a': 'a = 2'}

# %%
r = await ggb.function("getValueString", ['l1'])
r
# Out:
# 'l1 = {(0.5, 0.8660254037844), (0.5, -0.8660254037844)}'

# %%
await ggb.command("A = (2, 0)")
await asyncio.sleep(.01)
ggb.comm.shared_objects
# Out:
# {'a': 'a = 1'}

# %%
r = await ggb.function("getValueString", ['l1'])
r
# Out:
# 'l1 = {(1, 0)}'

# %%
await ggb.command("A = (3, 0)")
await asyncio.sleep(.01)
ggb.comm.shared_objects
# Out:
# {'a': 'a = 1'}

# %%
r = await ggb.function("getValueString", ['l1'])
r
# Out:
# 'l1 = {(?, ?)}'

# %% [markdown]
# ## with ipywidgets

# %%
import ipywidgets as widgets

# %%
label = widgets.Label(value=ggb.comm.shared_objects['a'])

# %%
display(label)
# Out:
# Label(value='a = 1')

# %%
async def on_shared_update(changes):
    # await asyncio.sleep(0)
    label.value = changes['a']

# %%
ggb.comm.add_shared_listener(on_shared_update)
# Out:
# True

# %%
ggb.comm.logs
# Out:
# ['Clients connected: 1 (connects+=1, disconnects+=0)',
#  'recv:type=probe',
#  'recv:type=start',
#  'post_execute: event probe',
#  'post_execute: event start',
#  'post_execute: flushed 2 recv_events',
#  'Unexpected response for id afcaffde-f747-4a4d-8ffc-d645c46f0b97',
#  'recv:type=created',
#  'recv:type=bulk_actions',
#  'Unexpected response for id 96cad5d7-8157-4436-805c-8e113a4e58df',
#  'post_execute: event add',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 2 recv_events',
#  'recv:type=created',
#  'Unexpected response for id 049406a7-94e9-4b31-b1fe-e69c7f4501fe',
#  'recv:type=bulk_actions',
#  'recv:type=created',
#  'recv:type=bulk_actions',
#  'Unexpected response for id 6220ae0b-ce53-4277-80fd-0e19c2fe5113',
#  'post_execute: event add',
#  'post_execute: event bulk_actions',
#  'post_execute: event add',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 4 recv_events',
#  'recv:type=created',
#  'recv:type=bulk_actions',
#  'Unexpected response for id c8940657-0143-4163-bbec-93b9b85f9bd9',
#  'post_execute: event add',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 2 recv_events',
#  'recv:type=created',
#  'Unexpected response for id 9ed99412-8c85-4855-911a-5244d1fe7dcd',
#  'recv:type=bulk_actions',
#  'post_execute: event add',
#  'post_execute: flushed 1 recv_events',
#  'recv:type=created',
#  'recv:type=bulk_actions',
#  'post_execute: event bulk_actions',
#  'post_execute: event add',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 3 recv_events',
#  'Unexpected response for id 806f9649-6aa1-4aac-bd80-4ab7fb9c198c',
#  'Clients connected: 1 (connects+=14, disconnects+=14)',
#  'recv:type=bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 2 recv_events',
#  'recv:type=listen',
#  'Unexpected response for id 13731d22-5bde-48de-84ae-74bca69780b3',
#  'Clients connected: 1 (connects+=2, disconnects+=2)',
#  'recv:type=created',
#  'Unexpected response for id 68e7e0bc-f9cd-4e06-8b01-dc6105f535d8',
#  'recv:type=value',
#  'Unexpected response for id 1fb92b4f-4769-46c0-9aad-b730f88ef41d',
#  'recv:type=bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 2 recv_events',
#  'recv:type=created',
#  'Unexpected response for id ed45b384-72b5-4341-800c-85c020e84316',
#  'recv:type=value',
#  'Unexpected response for id 7b58420f-b246-4a0b-9e86-c966bd7da396',
#  'recv:type=created',
#  'Unexpected response for id 89bcc3b8-3480-4373-a8ae-846c2b5d5ab5',
#  'Clients connected: 1 (connects+=6, disconnects+=6)',
#  'recv:type=value',
#  'Clients connected: 1 (connects+=1, disconnects+=1)',
#  'recv:type=bulk_actions',
#  'recv:type=bulk_actions',
#  'recv:type=bulk_actions',
#  'recv:type=bulk_actions',
#  'recv:type=bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: event shared_objects_update',
#  'post_execute: event bulk_actions',
#  'post_execute: flushed 10 recv_events']

# %% [markdown]
# ## clear

# %%
ggb.comm.remove_shared_listener(on_shared_update)
# Out:
# True

# %%
ggb.comm.clear_shared_listner()
# Out:
# 0

# %%
r = await ggb.listen('a', False)
