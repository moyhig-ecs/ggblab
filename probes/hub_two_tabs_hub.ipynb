# %% [markdown]
# # hub-crossing ⑥ on the live Hub (2026-09-15): two tabs → one live applet per document
#
# Run on AKS `vioras2025` / user `ggblab-probe` / image `binder:9.0.2-v2test` (Playwright). Results: RECORD_ggblab_v2_hub_crossing_test_20260915.md §2-3 (lancedb-rag). The 5-cell local variant is `hub_two_tabs.ipynb`.

# %%
from ggblab import GeoGebra
g = GeoGebra()
print('mount', g.mount_id, '| server', g.server_url)
g

# %%
import time; t0 = time.time()
labels = g.command('A=(1,2)', 'B=(4,1)', timeout=30)
print('LABELS', labels, 'after', round(time.time()-t0, 2), 's')
