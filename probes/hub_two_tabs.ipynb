# %% [markdown]
# # hub-crossing ⑥ probe (2026-09-15): two tabs / reload / second output → one live applet per document

# %%
from ggblab import GeoGebra
g = GeoGebra()
print('mount', g.mount_id)
g

# %%
import time; t0 = time.time()
labels = g.command('A=(1,2)', 'B=(4,1)', timeout=30)
print('LABELS', labels, 'after', round(time.time()-t0, 2), 's')

# %%
g   # a second output for the same document on the same page → pointer, not a second applet

# %%
GeoGebra()   # a SECOND object for the same document on the same page → pointer, not a second applet
